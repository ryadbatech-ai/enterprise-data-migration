# %% [markdown]
# # Databricks demo
# Portfolio deployment template for the enterprise data migration pipeline.

# %%
# In Databricks, import the src package and call the pipeline modules.
# This notebook is intentionally anonymized and does not connect to real systems.
